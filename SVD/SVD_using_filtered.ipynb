# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv('/content/drive/MyDrive/집교 2_Team P/user-track-listen_count_filtered5.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   user_id  track_id  listen_count_bin
# 0           0  21072247         2                 5
# 1           1  32226961         2                 5
# 2           2   2115525         2                 5
# 3           3   4812967         2                 3
# 4           4  21211675         2                 1

# %%
from scipy.sparse import csr_matrix

# %%
# !pip install surprise
from surprise import SVD
from surprise import Dataset, Reader
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV
from surprise.model_selection import cross_validate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163760 sha256=b6ce3c9eac391a2c09f046494c7669eacc26524d67c73657e016b96d303996aa
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %%
unique_users = df['user_id'].nunique()
unique_tracks = df['track_id'].nunique()

print(f'Unique Users: {unique_users}')
print(f'Unique Tracks: {unique_tracks}')
# Out:
# Unique Users: 23761
# Unique Tracks: 28378

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id', 'track_id', 'listen_count_bin']], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=64, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)

print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# RMSE: 1.0332
# MAE:  0.7702
# RMSE: 1.0331769519552871
# MAE: 0.7702442361303129

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=128, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0255
# MAE:  0.7633

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=256,random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0223
# MAE:  0.7647

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=256,n_epochs=50, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0278
# MAE:  0.7631

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=512,n_epochs=50, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0092
# MAE:  0.7589

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=512, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0233
# MAE:  0.7719

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=768, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0273
# MAE:  0.7796

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=768,n_epochs=50, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0042
# MAE:  0.7599

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=1024, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0325
# MAE:  0.7870

# %%
# SVD 모델 초기화 및 학습
model = SVD(n_factors=2048, random_state=42)  # n_factors는 잠재 요인의 수를 지정합니다.
model.fit(trainset)

# 테스트 데이터에 대한 예측
predictions = model.test(testset)

# 성능 평가 (RMSE 등)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 1.0517
# MAE:  0.8087

# %%
param_grid = {'n_factors': [160],
              'n_epochs': [100],
              'lr_all': [0.001, 0.005],
              'reg_all': [0.08, 0.1]}

# %%
# grid_search_svd = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=3, joblib_verbose=4, n_jobs=-2)

# %%
# # find the best parameters for the model
# grid_search_svd.fit(data)
# find_algo = grid_search_svd.best_estimator['rmse']
# print(grid_search_svd.best_score['rmse'])
# print(grid_search_svd.best_params['rmse'])

# %%
# # Perform the cross validation
# cross_validate(find_algo, data, measures=['RMSE'], cv=5, verbose=True)

# %%
final_algorithm = SVD(n_factors=160, n_epochs=100, lr_all=0.005, reg_all=0.1)
final_algorithm.fit(trainset)
test_predictions = final_algorithm.test(testset)
print(f"The RMSE is {accuracy.rmse(test_predictions, verbose=True)}")

# %%
import pickle

# %%
with open('/content/drive/MyDrive/집교 2_Team P/svd_model.pkl', 'wb') as file:
    pickle.dump(final_algorithm, file)

# %%
# 저장된 모델 불러오기
with open('/content/drive/MyDrive/집교 2_Team P/svd_model.pkl', 'rb') as file:
    loaded_svd = pickle.load(file)

# %%
test_predictions = loaded_svd.test(testset)
print(f"The RMSE is {accuracy.rmse(test_predictions, verbose=True)}")

# %%
embedding1 = pd.read_pickle('/content/drive/MyDrive/집교 2_Team P/lyrics_Embedding/all_embeddings_part1.pkl의 사본')
